# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
N_neurons_vec = [5, 10, 20 ,30, 50, 75, 100]
with open('paramscan_l2regularization_PNN_PEPG_MNIST_run3.pkl', 'rb') as f:
    results = pickle.load(f)

print(len(results))
# Out:
# 7

# %%
D = results[0]

# %%
plt.loglog(D['train_loss'])

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for k, n_neurons in enumerate(N_neurons_vec):
    # Train loss
    axs[0].loglog(results[k]['train_loss'], label=f"{n_neurons}")
    axs[0].set_title("Train Loss")
    axs[0].set_xlabel("Epoch")
    axs[0].set_ylabel("Loss")

    # Test loss
    axs[1].loglog(results[k]['test_loss'], label=f"{n_neurons}")
    axs[1].set_title("Test Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].set_ylabel("Loss")

axs[0].legend(title="N_neurons")
axs[1].legend(title="N_neurons")

plt.tight_layout()
plt.show()

# %%
np.max(D['test_acc'])
# Out:
# 94.31

# %%
print(D['time']/3600)
# Out:
# 16.290698093705707

# %%
with open('75_overfit_batch1k_popsize1percent_PNN_PEPG_MNIST.pkl', 'rb') as f:
    results_new = pickle.load(f)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

# Train loss
axs[0].loglog(results[5]['train_loss'], label="\sigma_{lim} = 1e-2")
axs[0].loglog(results_new[0]['train_loss'], label="\sigma_{lim} = 1e-5")

axs[0].set_title("Train Loss")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")

# Test loss
axs[1].loglog(results[5]['test_loss'], label="\sigma_{lim} = 1e-2")
axs[1].loglog(results_new[0]['test_loss'], label="\sigma_{lim} = 1e-5")
axs[1].set_title("Test Loss")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")

axs[0].legend(title="")
axs[1].legend(title="")


plt.tight_layout()
plt.show()

# %%
with open('100pca_overfit_batch1k_popsize1percent_PNN_PEPG_MNIST.pkl', 'rb') as f:
    results_pca = pickle.load(f)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

# Train loss
axs[0].loglog(results[-1]['train_loss'], label="OG data")
axs[0].loglog(results_pca[0]['train_loss'], label="PCA 81")

axs[0].set_title("Train Loss")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")

# Test loss
axs[1].loglog(results[-1]['test_loss'], label="OG data")
axs[1].loglog(results_pca[0]['test_loss'], label="PCA 81")
axs[1].set_title("Test Loss")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")

axs[0].legend(title="")
axs[1].legend(title="")


plt.tight_layout()
plt.show()

# %%
import os
print(os.getcwd())
# Out:
# g:\Utilisateurs\anas.skalli\Desktop\Projects\nonlinear_oscillator_network\MNIST\results

# %%
files = os.listdir(".")  # "." means current directory
print(files)
# Out:
# ['1000_overfit_batch128_PNN_PEPG_MNIST.pkl', '1000_overfit_batch128_popsize100_PNN_PEPG_MNIST.pkl', '1000_overfit_batch128_popsize1percent_PNN_PEPG_MNIST.pkl', '50_10_20_30_paramscan_PNN_PEPG_MNIST.pkl', '5_10_paramscan_PNN_PEPG_MNIST.pkl', '75_overfit_batch1k_popsize1percent_PNN_PEPG_MNIST.pkl', 'check_plot.ipynb', 'paramscan_PNN_BP_MNIST.pkl', 'paramscan_PNN_PEPG_MNIST.pkl', 'paramscan_PNN_SPSA_MNIST.pkl', 'paramscan_PNN_SPSA_MNIST_2.pkl', 'PNN_PEPG_50neurons_MNIST.pkl']

# %%
with open('paramscan_PNN_BP_MNIST.pkl', 'rb') as f:
    results_BP = pickle.load(f)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for k, n_neurons in enumerate(N_neurons_vec):
    # Train loss
    axs[0].loglog(results_BP[k]['train_loss'], label=f"{n_neurons}")
    axs[0].set_title("Train Loss")
    axs[0].set_xlabel("Epoch")
    axs[0].set_ylabel("Loss")

    # Test loss
    axs[1].loglog(results_BP[k]['test_loss'], label=f"{n_neurons}")
    axs[1].set_title("Test Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].set_ylabel("Loss")

axs[0].legend(title="N_neurons")
axs[1].legend(title="N_neurons")

plt.tight_layout()
plt.show()

# %%
BP_acc_vec = []
for k in range(len(N_neurons_vec)):
    BP_acc_vec.append(np.max(results_BP[k]['test_acc']))

# %%
plt.plot(N_neurons_vec,BP_acc_vec)

# %%
np.max(results[-5]['test_acc'])
# Out:
# 92.99

# %%
import torch

# %%
len(results_pca[0]['test_loss'])
# Out:
# 4200

# %%
4200/6
# Out:
# 700.0

# %%
with open('100_l2regularization_overfit_PNN_PEPG_MNIST_2.pkl', 'rb') as f:
    results_reg = pickle.load(f)

# %%
plt.loglog(results_reg[0]['test_loss'])
